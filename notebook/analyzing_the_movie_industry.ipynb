# %%
# Importing necessary packages

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib

plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 8)

pd.options.mode.chained_assignment = None

# Reading the data
df = pd.read_csv('/content/movies.csv')

# %%
#Viewing the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Checking for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# Data types for columns

print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Handle NaN values before converting to int64

df['budget'] = df['budget'].fillna(0).astype('int64')
df['gross'] = df['gross'].fillna(0).astype('int64')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Correcting the year column

df['yearcorrect'] = df['released'].astype(str)[:4]

# %%
# Sorting data by gross revenue

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
pd.set_option('display.max_rows', 50)

# %%
# Dropping the duplicates

df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Hypotheses

# Budget high correlation

# Company high correlation

# %%
import matplotlib.pyplot as plt

# Set the figure and axes background color
plt.figure(facecolor='#01242E')  # Set the background color of the figure
ax = plt.gca()
ax.set_facecolor('#01242E')  # Set the background color of the plot

# Create scatter plot with specified colors
plt.scatter(x=df['budget'], y=df['gross'], color='#F1DE71')  # Set the color of the points
plt.title('Budget vs Gross Earnings', color='#F1DE71')  # Set the color of the title
plt.xlabel('Gross Earnings', color='#F1DE71')  # Set the color of the x-axis label
plt.ylabel('Film Budget', color='#F1DE71')  # Set the color of the y-axis label

# Set the color of the tick labels
ax.tick_params(colors='#F1DE71')  # Change the color of the tick labels

# Customize the grid
ax.grid(color='#355760', linestyle='-', linewidth=0.5)  # Set a less visible grid color and thinner lines

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the background and grid color before plotting
plt.figure(facecolor='#01242E')  # Set the background color of the figure
ax = plt.gca()
ax.set_facecolor('#01242E')  # Set the background color of the plot

# Customize the grid
ax.grid(color='#355760', linestyle='-', linewidth=0.5)  # Set a less visible grid color and thinner lines

# Create the Seaborn regression plot
sns.regplot(x='budget', y='gross', data=df,
            scatter_kws={"color": "#F1DE71"},  # Set scatter plot color
            line_kws={"color": "black"})  # Set regression line color to black

# Customize the title and labels
plt.title('Budget vs Gross Earnings', color='#F1DE71')
plt.xlabel('Gross Earnings', color='#F1DE71')
plt.ylabel('Film Budget', color='#F1DE71')

# Set the color of the tick labels
ax.tick_params(colors='#F1DE71')  # Change the color of the tick labels

plt.show()

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
# High correlation between budget and gross earnings

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()

# Format the annotations to show only two digits after the decimal point
formatted_corr_matrix = correlation_matrix.round(2)

# Define a custom colormap centered around the accent color
from matplotlib.colors import LinearSegmentedColormap

custom_cmap = LinearSegmentedColormap.from_list(
    "custom_cmap",
    ["#01242E", "#F1DE71", "#F1DE71", "#F1DE71", "#01242E"],
    N=256
)

# Set the background and grid color before plotting
plt.figure(facecolor='#01242E')  # Set the background color of the figure
ax = plt.gca()
ax.set_facecolor('#01242E')  # Set the background color of the plot

# Create the heatmap with the specified custom colormap and formatted annotations
sns.heatmap(formatted_corr_matrix, annot=True, cmap=custom_cmap, linewidths=0.5,
            linecolor='#01242E',  # Set the color of the grid lines to dark blue
            cbar_kws={'ticks': [-1, -0.5, 0, 0.5, 1]},  # Customize the color bar ticks
            annot_kws={'color': '#01242E'})  # Set the annotation color to dark blue for contrast

# Customize the title and labels
plt.title('Correlation Matrix for Numeric Features', color='#F1DE71')
plt.xlabel('Features', color='#F1DE71')
plt.ylabel('Features', color='#F1DE71')

# Set the color of the tick labels
ax.tick_params(colors='#F1DE71')  # Change the color of the tick labels

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming df is your DataFrame
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()

# Format the annotations to show only two digits after the decimal point
formatted_corr_matrix = correlation_matrix.round(2)

# Define a custom colormap centered around the accent color
from matplotlib.colors import LinearSegmentedColormap

custom_cmap = LinearSegmentedColormap.from_list(
    "custom_cmap",
    ["#01242E", "#F1DE71", "#F1DE71", "#F1DE71", "#01242E"],
    N=256
)

# Set the background and grid color before plotting
plt.figure(facecolor='#01242E')  # Set the background color of the figure
ax = plt.gca()
ax.set_facecolor('#01242E')  # Set the background color of the plot

# Create the heatmap with the specified custom colormap and formatted annotations
sns.heatmap(formatted_corr_matrix, annot=True, cmap=custom_cmap, linewidths=0.5,
            linecolor='#01242E',  # Set the color of the grid lines to dark blue
            cbar_kws={'ticks': [-1, -0.5, 0, 0.5, 1]},  # Customize the color bar ticks
            annot_kws={'color': '#01242E'})  # Set the default annotation color to dark blue

# Customize the title and labels
plt.title('Correlation Matrix for Numeric Features', color='#F1DE71')
plt.xlabel('Features', color='#F1DE71')
plt.ylabel('Features', color='#F1DE71')

# Set the color of the tick labels
ax.tick_params(colors='#F1DE71')  # Change the color of the tick labels

# Modify the annotation color conditionally for values that are 1
for text in ax.texts:
    if text.get_text() == '1.00':
        text.set_color('#F1DE71')  # Set the font color to the accent color for values that are 1

plt.show()

# %%
# Looking at the companies

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       193    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2817    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7.0      2165    3344
#
# ...

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0  1047       54  19000000   46998772     2319    146.0            1
# 1   327       55   4500000   58853106      731    104.0            0
# 2  1745       55  18000000  538375067     1540    124.0            2
# 3  2246       55   3500000   83453539     1812     88.0            0
# 4   410       55   6000000   39846344     1777     98.0           -1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Calculate correlation matrix
correlation_matrix = df_numerized.corr(method='pearson')

# Round the values in the correlation matrix to two decimal places
formatted_corr_matrix = correlation_matrix.round(2)

# Define a custom colormap centered around the accent color
from matplotlib.colors import LinearSegmentedColormap

custom_cmap = LinearSegmentedColormap.from_list(
    "custom_cmap",
    ["#01242E", "#F1DE71", "#F1DE71", "#F1DE71", "#01242E"],
    N=256
)

# Set the background and grid color before plotting
plt.figure(facecolor='#01242E')  # Set the background color of the figure
ax = plt.gca()
ax.set_facecolor('#01242E')  # Set the background color of the plot

# Create the heatmap with annotations
sns.heatmap(formatted_corr_matrix, annot=True, cmap=custom_cmap, fmt='.2f', linewidths=0.5,
            cbar_kws={'ticks': [-1, -0.5, 0, 0.5, 1]},  # Customize the color bar ticks
            annot_kws={'color': '#F1DE71'})  # Set the annotation color to the accent color

# Customize the title and labels
plt.title('Correlation Matrix for Numeric Features', color='#F1DE71')
plt.xlabel('Features', color='#F1DE71')
plt.ylabel('Features', color='#F1DE71')

# Set the color of the tick labels
ax.tick_params(colors='#F1DE71')  # Change the color of the tick labels

# Modify the cell colors based on their values
for i in range(len(formatted_corr_matrix)):
    for j in range(len(formatted_corr_matrix.columns)):
        value = formatted_corr_matrix.iloc[i, j]
        color = '#F1DE71' if np.isclose(value, 1.0) else '#01242E'  # Use accent color for values close to 1, otherwise dark blue
        plt.gca().get_children()[i * len(formatted_corr_matrix.columns) + j].set_facecolor(color)

# Change the font color of values equal to 1 to white
for i in range(len(formatted_corr_matrix)):
    for j in range(len(formatted_corr_matrix.columns)):
        value = formatted_corr_matrix.iloc[i, j]
        if np.isclose(value, 1.0):
            ax.texts[i * len(formatted_corr_matrix.columns) + j].set_color('white')
        else:
            ax.texts[i * len(formatted_corr_matrix.columns) + j].set_color('#F1DE71')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-83e6d5eeab59> in <cell line: 39>()
#      41         value = formatted_corr_matrix.iloc[i, j]
#      42         color = '#F1DE71' if np.isclose(value, 1.0) else '#01242E'  # Use accent color for values close to 1, otherwise dark blue
# ---> 43         plt.gca().get_children()[i * len(formatted_corr_matrix.columns) + j].set_facecolor(color)
#      44
#      45 # Change the font color of values equal to 1 to white
#
# AttributeError: 'Text' object has no attribute 'set_facecolor'

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score        0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes        0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.055665
# ...

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#                               ...
# yearcorrect  budget        -0.006007
#              gross          0.023640
#              company        0.007750
#              runtime        0.016698
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.334021
# budget       genre         -0.334021
# genre        gross         -0.234297
# gross        genre         -0.234297
# votes        genre         -0.145307
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[sorted_pairs > 0.5]

high_corr
# Out:
# gross        votes          0.632834
# votes        gross          0.632834
# budget       gross          0.750157
# gross        budget         0.750157
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earnings

# Company has a low correlation

# %% [markdown]
# Thank You!
